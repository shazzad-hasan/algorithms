# %% [markdown]
# <a href="https://colab.research.google.com/github/shazzad-hasan/Algorithms/blob/main/image_classification/cat_vs_dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World
